# %% [markdown]
# <a href="https://colab.research.google.com/github/Asilbek1420/RestaurantTest/blob/main/TestArrivalV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the official YOLOv8 library from Ultralytics
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.5 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
import os

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wDkXkq1p6HgQkEouDCMQ")
project = rf.workspace("asilbek-o8cxr").project("testarrivalv3-q5bce")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# Train YOLOv8 on the dataset from Roboflow
# model: yolov8n.pt = nano (smallest), change to yolov8s.pt or yolov8m.pt for better accuracy
# !yolo detect train data={dataset.location}/data.yaml model=yolov8m.pt epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("runs/detect/train3/weights/best.pt")

# Perform object detection on an image using the model
results = model("/content/TestArrivalV3-3/train/images/frame_0009_jpg.rf.825fd00d64325bdbd37e7d21d444753c.jpg")
# Out:
# image 1/1 /content/TestArrivalV3-3/train/images/frame_0009_jpg.rf.825fd00d64325bdbd37e7d21d444753c.jpg: 384x640 4 customers, 14 tabless, 26.9ms
# Speed: 2.3ms preprocess, 26.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
from google.colab import files
files.download('/content/TestArrivalV3-3/train/images/frame_0009_jpg.rf.825fd00d64325bdbd37e7d21d444753c.jpg')  # Replace with your actual file name
